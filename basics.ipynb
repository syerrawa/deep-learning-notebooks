# %% [markdown]
# <a href="https://colab.research.google.com/github/syerrawa/deep-learning-notebooks/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers
from keras.datasets import mnist

# %%
x = np.array(12)
x
# Out:
# array(12)

# %%
x = np.array([4, 5, 9, 12])
x
# Out:
# array([ 4,  5,  9, 12])

# %% [markdown]
# ### No. of axes for the tensor

# %%
x.ndim
# Out:
# 1

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax")
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8998 - loss: 0.3620
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9514 - loss: 0.1689
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9643 - loss: 0.1217
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9729 - loss: 0.0943
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9779 - loss: 0.0765

# %%
predictions = model.predict(test_images)
predictions.shape
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (10000, 10)

# %%
print(predictions[150].argmax())
# Out:
# 9

# %%
metrics = model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9719 - loss: 0.0887

# %%
print(f"Loss: {metrics[0]}, Accuracy: {metrics[1]}")
# Out:
# Loss: 0.08866139501333237, Accuracy: 0.9718999862670898

# %%
y = np.random.random((10,))
y.shape
# Out:
# (10,)

# %%
y = np.expand_dims(y, axis=0)
y.shape
# Out:
# (1, 10)

# %%
test = np.ones((3, 2, 5))
test.shape
# Out:
# (3, 2, 5)

# %%
test = np.expand_dims(test, axis=0)
test.shape
# Out:
# (1, 3, 2, 5)

# %%
test = np.transpose(test)
test.shape
# Out:
# (5, 2, 3, 1)
